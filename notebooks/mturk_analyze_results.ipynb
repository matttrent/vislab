# %%
# %load_ext autoreload
# %autoreload 2

import sys
import uuid
import math
import urllib
import urlparse
import time

from boto.mturk.connection import *
from boto.mturk.question import ExternalQuestion
from boto.mturk.qualification import *
from boto.mturk.price import *

import pandas as pd
import vislab.datasets
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
answer_df = pd.read_hdf( '../../mturk-results/mturk-answers.h5', 'df' )
print len( answer_df )
answer_df.head()
# Out:
# 108564
#                               assignment_id                          hit_id  \
# 12750600883  3DZQRBDBSLEAV2ZYGLOU1XEOXCR3S0  3T2EL38U0LJ8C0T5I41BOTS8ILLXQB
# 3640743068   3DZQRBDBSLEAV2ZYGLOU1XEOXCR3S0  3T2EL38U0LJ8C0T5I41BOTS8ILLXQB
# 12664369395  3DZQRBDBSLEAV2ZYGLOU1XEOXCR3S0  3T2EL38U0LJ8C0T5I41BOTS8ILLXQB
# 11617034266  3DZQRBDBSLEAV2ZYGLOU1XEOXCR3S0  3T2EL38U0LJ8C0T5I41BOTS8ILLXQB
# 13317660883  3DZQRBDBSLEAV2ZYGLOU1XEOXCR3S0  3T2EL38U0LJ8C0T5I41BOTS8ILLXQB
#
#             tagged_Bright tagged_Depth_of_Field tagged_Detailed  \
# 12750600883           NaN                   NaN             NaN
# 3640743068            NaN                   NaN             NaN
# 12664369395           NaN                   NaN             NaN
# 11617034266           NaN                   NaN             NaN
# 13317660883           NaN                   NaN             NaN
#
#             tagged_Ethereal tagged_Geometric_Composition tagged_HDR  \
# 12750600883             NaN                          NaN        NaN
# 3640743068              NaN                          NaN        NaN
# 12664369395             NaN                          NaN        NaN
# 11617034266             NaN                          NaN        NaN
# 13317660883             NaN                          NaN        NaN
#
#             tagged_Hazy tagged_Horror tagged_Long_Exposure tagged_Macro  \
# 12750600883         NaN           NaN                  NaN          NaN
# 3640743068          NaN           NaN                  NaN          NaN
# 12664369395         NaN           NaN                  NaN          NaN
# 11617034266         NaN           NaN                  NaN          NaN
# 13317660883         NaN           NaN                  NaN          NaN
#
#             tagged_Melancholy tagged_Minimal tagged_Noir tagged_Pastel  \
# 12750600883               NaN            NaN         NaN         False
# 3640743068                NaN            NaN         NaN         False
# 12664369395               NaN            NaN         NaN         False
# 11617034266               NaN            NaN         NaN         False
# 13317660883               NaN            NaN         NaN         False
#
#             tagged_Romantic tagged_Serene tagged_Sunny tagged_Vintage
# 12750600883             NaN           NaN          NaN            NaN ...
# 3640743068              NaN           NaN          NaN            NaN ...
# 12664369395             NaN           NaN          NaN            NaN ...
# 11617034266             NaN           NaN          NaN            NaN ...
# 13317660883             NaN           NaN          NaN            NaN ...
#
# [5 rows x 21 columns]

# %%
result_df = pd.read_hdf( '../../mturk-results/mturk-results.h5', 'df' )
print len( result_df )
result_df.head()
# Out:
# 26315
#                               assignment_id  conf_Bright  conf_Depth_of_Field  \
# 10002847526  3GFK2QRXX9G6GY3BE9MODJFTITC5WM          NaN                  NaN
# 10004268914  30BXRYBRP4WIWRN6FBNX2GIJNVAWHN          NaN                  NaN
# 10004468814  3TYCR1GOTCIOCIB1HJM2TC58LM0LZ2          NaN                  NaN
# 10004487845  3HHRAGRYX84HCCWLQD8V85790FB9O3          NaN                  NaN
# 10007199026  34T446B1C0DY7TB50CGBKUCZ93GC0S          NaN                  NaN
#
#              conf_Detailed  conf_Ethereal  conf_Geometric_Composition  \
# 10002847526            NaN            NaN                         NaN
# 10004268914            NaN              0                         NaN
# 10004468814       0.666667            NaN                         NaN
# 10004487845       0.666667            NaN                         NaN
# 10007199026            NaN            NaN                         NaN
#
#              conf_HDR  conf_Hazy  conf_Horror  conf_Long_Exposure  conf_Macro  \
# 10002847526       NaN        NaN          NaN                   0         NaN
# 10004268914       NaN        NaN          NaN                 NaN         NaN
# 10004468814       NaN        NaN          NaN                 NaN         NaN
# 10004487845       NaN        NaN          NaN                 NaN         NaN
# 10007199026       NaN        NaN          NaN                 NaN         NaN
#
#              conf_Melancholy  conf_Minimal  conf_Noir  conf_Pastel  \
# 10002847526              NaN           NaN        NaN          NaN
# 10004268914                0           NaN        NaN          NaN
# 10004468814              NaN           NaN        NaN          NaN
# 10004487845              NaN           NaN        NaN          NaN
# 10007199026              NaN           NaN        NaN          NaN
#
#              conf_Romantic  conf_Serene  conf_Sunny  conf_Vintage  \
# 10002847526            NaN          NaN         NaN           NaN
# 10004268914            NaN          NaN         NaN           NaN
# 10004468814            NaN          NaN         NaN           NaN
# 10004487845            NaN          NaN         NaN           NaN
# 10007199026              0          NaN         NaN           NaN
#
#                                      hit_id
# 10002847526  3BFF0DJK8WBD8ZZY5YPJUQM3OT9TS1 ...
# 10004268914  3PA41K45VM3TX9MZ0EIOUPPACB07PA ...
# 10004468814  322ZSN9Z5FJU6EXNFXT1WN6XAD7T4V ...
# 10004487845  3087LXLJ6LF3OLXL1C1A3G1J1CTF06 ...
# 10007199026  35F6NGNVM7IRP1F6HVR8ZZQ71E47TY ...
#
# [5 rows x 63 columns]

# %%
style_cols = [name for name in result_df.columns if 'style' in name]
style_cols.remove( 'style_Bokeh' )
style_cols.remove( 'style_Texture' )
print style_cols
# Out:
# ['style_Bright', 'style_Depth_of_Field', 'style_Detailed', 'style_Ethereal', 'style_Geometric_Composition', 'style_HDR', 'style_Hazy', 'style_Horror', 'style_Long_Exposure', 'style_Macro', 'style_Melancholy', 'style_Minimal', 'style_Noir', 'style_Pastel', 'style_Romantic', 'style_Serene', 'style_Sunny', 'style_Vintage']

# %% [markdown]
# # Helper functions

# %%
def assignment_df_tag( df, drop=True ):
    if drop: df = df.dropna( axis=1 )
    return [name for name in df.columns.tolist() if 'tagged' in name][0]

def assignment_series_tag( ser, drop=True ):
    if drop: ser = ser.dropna()
    return [name for name in ser.index.tolist() if 'tagged' in name][0]

# %% [markdown]
# ## Worker distribution

# %%
# total number of unique workers
unique_workers = answer_df.drop_duplicates( cols=['worker_id'] )['worker_id'].tolist()
print len( unique_workers )
# Out:
# 538

# %%
answers_per_worker = [ len( answer_df[ answer_df['worker_id'] == worker_id ] ) 
                       for worker_id in unique_workers ]
answers_per_worker = pd.DataFrame( answers_per_worker, index=unique_workers, columns=['count'] )
answers_per_worker.sort( columns='count', ascending=False, inplace=True )

# %%
# with the exception of one person, everyone obeyed the only-do-1-hit-per-style rule
answers_per_worker.head(15)
# Out:
#                 count
# A9K0CV70JWG1W    3396
# A1QCQE5XW37LN1   2568
# A2CSQNLTE06WZS   2206
# ADJ9I7ZBFYFH7    1920
# A35Z1QH3JQEZG6   1788
# AEVU71Z2FDTUX    1718
# A340DZFTU1OSQQ   1704
# A1HGC1W5EWXUYS   1680
# AA7BTDZQNHW5     1632
# A3DFJV1RD653DQ   1472
# A2SHY0YV9UW6SC   1272
# A18TXM6GMU1411   1260
# A2M5VW97GIYLHB   1236
# A37WXDYYT7RCZ0   1200
# A18RDBJFY3QWZL   1198
#
# [15 rows x 1 columns]

# %%
plt.rcParams['figure.figsize'] = ( 16, 8 )

plt.plot( range( len( answers_per_worker ) ), answers_per_worker['count'] )
plt.ylabel( 'num answers' )
plt.xlabel( 'worker' )

# %% [markdown]
# # Assignment answer distribution

# %%
assignments = answer_df.drop_duplicates( cols=['assignment_id'] )['assignment_id'].tolist()
print len( assignments )

assign_means = []
for assign in assignments:
    assign_df = answer_df[ answer_df['assignment_id'] == assign ]

    tag_col = assignment_df_tag( assign_df )

    assign_means += [ assign_df[ tag_col ].astype( 'int' ).mean() ]
# Out:
# 9137

# %%
print len( assign_means )
print assign_means[:10]
# Out:
# 9137
# [0.10000000000000001, 0.40000000000000002, 0.40000000000000002, 0.29999999999999999, 0.29999999999999999, 0.29999999999999999, 0.5, 0.59999999999999998, 0.5, 0.5]

# %%
plt.rcParams['figure.figsize'] = ( 8, 6 )

plt.hist( assign_means, bins=10, range=(0,1) )
plt.xlabel( 'percent answered true' )
plt.ylabel( 'number of assignments' )
axs = plt.axis()
axs = [ 0, 1 ] + list( axs[2:] )
plt.axis( axs )

# %% [markdown]
# In this plot, we've looked at each assignment individually, computed the perecent of the 10 questions that were answered true.  This plot is a histogram of those percentages.  Across all assignments, we see a pretty good distribution centered around 50% of the images being of the style, with a slight bias towards less than half.

# %% [markdown]
# # Assignment outliers

# %%
assign_allone_df = pd.DataFrame()

for assign in assignments:
    assign_df = answer_df[ answer_df['assignment_id'] == assign ]
    
    tag_col = assignment_df_tag( assign_df )

    update = False
    if len( assign_df[ assign_df[tag_col] == True ] ) is len( assign_df ):
        update = True
    if len( assign_df[ assign_df[tag_col] == False ] ) is len( assign_df ):
        update = True
        
    if update:
        assign_allone_df = pd.concat( [ assign_allone_df, assign_df ] )

# %%
assign_allone_df.head()
# Out:
#                               assignment_id                          hit_id  \
# 12403000954  3FFJ6VRIL1NPKWX5SMCXVXAUL250IA  379OL9DBSRDRK62T6YCRLC9SARB9Y7
# 13302473255  3FFJ6VRIL1NPKWX5SMCXVXAUL250IA  379OL9DBSRDRK62T6YCRLC9SARB9Y7
# 13151886894  3FFJ6VRIL1NPKWX5SMCXVXAUL250IA  379OL9DBSRDRK62T6YCRLC9SARB9Y7
# 12194759193  3FFJ6VRIL1NPKWX5SMCXVXAUL250IA  379OL9DBSRDRK62T6YCRLC9SARB9Y7
# 13313079965  3FFJ6VRIL1NPKWX5SMCXVXAUL250IA  379OL9DBSRDRK62T6YCRLC9SARB9Y7
# 11455582105               NaN            NaN         NaN           NaN
# 12775809235               NaN            NaN         NaN           NaN
# 11441805723               NaN            NaN         NaN           NaN
# 13107676534              True            NaN         NaN           NaN
# 11366640956               NaN            NaN         NaN           NaN
# 13138003243               NaN            NaN         NaN           NaN
# 9584007214                NaN            NaN         NaN           NaN
# 11912512444               NaN            NaN         NaN           NaN
# 12936267024               NaN            NaN         NaN           NaN
# 11860962993               NaN            NaN         NaN           NaN
#
#             tagged_Romantic tagged_Serene tagged_Sunny tagged_Vintage
# 12403000954           False           NaN          NaN            NaN ...
# 13317267575             NaN           NaN          NaN            NaN ...
# 9094477203              NaN          True          NaN            NaN ...
# 10364524243             NaN           NaN          NaN            NaN ...
# 13277235675             NaN           NaN          NaN            NaN ...
# 3431672963            False           NaN          NaN            NaN ...
# 13245458034             NaN           NaN          NaN            NaN ...
# 13223943755             NaN           NaN          NaN            NaN ...
# 10255866694             NaN           NaN          NaN            NaN ...
# 13215192085           False           NaN          NaN            NaN ...
# 13215192085           False           NaN          NaN            NaN ...
# 12998393875             NaN           NaN          NaN            NaN ...
# 13252567255             NaN           NaN          NaN            NaN ...
# 13035627133             NaN           NaN          NaN            NaN ...
# 13171845165             NaN           NaN          NaN            NaN ...
# 515217869               NaN           NaN          NaN            NaN ...
# 11947835804             NaN           NaN          NaN            NaN ...
# 8710649981              NaN           NaN          NaN            NaN ...
# 12711085895             NaN          True          NaN            NaN ...
# 12711085895             NaN          True          NaN            NaN ...
# 13124713973             NaN           NaN          NaN            NaN ...
# 13222912413             NaN           NaN          NaN            NaN ...
# 12601035405             NaN          True          NaN            NaN ...
# 13089687623             NaN           NaN          NaN            NaN ...
# 9700306653              NaN          True          NaN            NaN ...
# 13056541743             NaN           NaN          NaN            NaN ...
# 11455582105             NaN           NaN         True            NaN ...
# 12775809235             NaN           NaN         True            NaN ...
# 11441805723             NaN           NaN          NaN            NaN ...
# 13107676534             NaN           NaN          NaN            NaN ...
# 11366640956             NaN           NaN          NaN            NaN ...
# 13138003243             NaN           NaN          NaN            NaN ...
# 9584007214              NaN           NaN          NaN            NaN ...
# 11912512444             NaN           NaN          NaN            NaN ...
# 12936267024             NaN           NaN          NaN            NaN ...
# 11860962993             NaN           NaN          NaN            NaN ...
#
# [36 rows x 21 columns]

# %%
allone_assigns = [ ( row['worker_id'], assignment_series_tag( row ) ) 
                   for index, row in assign_allone_df.iterrows() ]
allone_assigns
# Out:
# [(u'AO3XB5I5QNNUI', 'tagged_Romantic'),
#  (u'A17UXYM7D324MI', 'tagged_Long_Exposure'),
#  (u'A109DH65MXHL0Q', 'tagged_Serene'),
#  (u'A109DH65MXHL0Q', 'tagged_Bright'),
#  (u'A109DH65MXHL0Q', 'tagged_Minimal'),
#  (u'AUKZKPLQ04H1E', 'tagged_Romantic'),
#  (u'A109DH65MXHL0Q', 'tagged_Detailed'),
#  (u'A17UXYM7D324MI', 'tagged_Geometric_Composition'),
#  (u'A35ARURSRU6UAZ', 'tagged_Pastel'),
#  (u'A2954VY4TK3RG7', 'tagged_Romantic'),
#  (u'A2Q934BD3J7AKE', 'tagged_Romantic'),
#  (u'A1PE0077HI218F', 'tagged_Detailed'),
#  (u'A2TC1ZFCTOCDA5', 'tagged_Melancholy'),
#  (u'A2TC1ZFCTOCDA5', 'tagged_Melancholy'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'AA7BTDZQNHW5', 'tagged_Depth_of_Field'),
#  (u'A1JTOUQAD12LQR', 'tagged_Detailed'),
#  (u'AQOYZ1NB7R5UY', 'tagged_Hazy'),
#  (u'A1JFZ5EX06Y8YV', 'tagged_Serene'),
#  (u'A31XNLA9REVGXL', 'tagged_Serene'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'A35NBUVLJDU499', 'tagged_Serene'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'A35NBUVLJDU499', 'tagged_Serene'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'A340DZFTU1OSQQ', 'tagged_Sunny'),
#  (u'A2C8HCH53HHIDQ', 'tagged_Sunny'),
#  (u'A33SMNMTMIOJ6T', 'tagged_Hazy'),
#  (u'AKLV0WIZZ356X', 'tagged_Melancholy'),
#  (u'A33SMNMTMIOJ6T', 'tagged_Hazy'),
#  (u'A9K0CV70JWG1W', 'tagged_Depth_of_Field'),
#  (u'A8545T2QRR936', 'tagged_Detailed'),
#  (u'A3C6BPE5UJ9EHR', 'tagged_Detailed'),
#  (u'A3E73BVSABJ7LM', 'tagged_Detailed'),
#  (u'A3E73BVSABJ7LM', 'tagged_Detailed')]

# %% [markdown]
# This is a list of all assignments where all of the answers were either True or False, which was only 9 out of the 495 assignments.  No particular style was represented more than twice, but 6 of the 9 were done by the same 2 workers.

# %%
# guy that answered 4 as all true or all false only completed 5 hits
# so 4/5 probably spam = reject
len( answer_df[ answer_df['worker_id'] == 'A109DH65MXHL0Q' ] )
# Out:
# 50

# %%
# guy that answered 2 as all true or all false completed 45 hits
# so probably ok
len( answer_df[ answer_df['worker_id'] == 'A17UXYM7D324MI' ] )
# Out:
# 450

# %% [markdown]
# I'd be interested in any other suggestions on how to validate worker answers.

# %% [markdown]
# # Per-style answer distribution

# %%
style_means = []

for sn in style_cols:
    
    tn = 'tagged_' + sn[6:]
    style_df = answer_df[ answer_df[tn].notnull() ]
    
    assignments = style_df.drop_duplicates( cols=['assignment_id'] )['assignment_id'].tolist()
    
    means = [ style_df[ style_df['assignment_id'] == assign ][tn].astype( 'int' ).mean()
              for assign in assignments ]
        
    style_means += [ means ]

# %%
print len( style_means )
# Out:
# 18

# %%
plt.rcParams['figure.figsize'] = ( 16, 18 )

for i, m in enumerate( style_means ):
    plt.subplot( 6, 3, i )
    plt.title( style_cols[i][6:] )
    plt.ylabel( 'n. assignments' )
    plt.hist( m, bins=5, range=(0,1) )
    axs = plt.axis()
    axs = [ 0, 1 ] + list( axs[2:] )
    plt.axis( axs )

# %% [markdown]
# Plots similar to the above all-assignment plot, but broken down by style.  We selected all the assignments corresponding to a given style, computed the percent tagged true in each assignment, and created a histogram.
#
# Most styles are pretty well distributed.  `Long_Exposure`, `Pastel`, `Romantic` and `Melancholy` all have biases toward marking less that 50% true, while several others have slight biases towards marking more than 50% true.

# %% [markdown]
# # Per-worker answer distribution

# %%
turker_means = []

for turker in answers_per_worker.index.tolist():
    
    worker_df = answer_df[ answer_df['worker_id'] == turker ]
    
    assignments = worker_df.drop_duplicates( cols=['assignment_id'] )['assignment_id'].tolist()
    
    means = []
    for assign in assignments:
        assign_df = worker_df[ worker_df['assignment_id'] == assign ]
        assign_df = assign_df.dropna( axis=1 )
        
        tag_cols = [name for name in assign_df.columns.tolist() if 'tagged' in name]
    
        means += [ assign_df[ tag_cols[0] ].astype( 'int' ).mean() ]
        
    turker_means += [ means ]

# %%
plt.rcParams['figure.figsize'] = ( 16, 16 )

for i, m in enumerate( turker_means[:15] ):
    plt.subplot( 6, 3, i+1 )
    plt.title( unique_workers[i] + ' : ' + str(len(m)) )
    plt.ylabel( 'n. assignments' )
    plt.hist( m, bins=5, range=(0,1) )
    axs = plt.axis()
    axs = [ 0, 1 ] + list( axs[2:] )
    plt.axis( axs )

# %% [markdown]
# Same style of plot, but broken down by turker, showing the top 15 turkers, all of which completed at least 10 HITs.  Again, a strong central distribution.

# %% [markdown]
# # Correctly answered

# %%
flickr_df = vislab.datasets.flickr.get_df()

# %%
sn = style_cols[0]
tn = 'tagged_' + sn[6:]
print sn, tn
# Out:
# style_Bright tagged_Bright

# %%
print len( result_df )
print len( result_df[ result_df[tn].isnull() ] )
print len( result_df ) - len( result_df[ result_df[tn].isnull() ] )
# Out:
# 26315
# 24893
# 1422

# %%
tag_df = result_df.dropna( subset=[tn] )

# %%
tag_df.head(9)[ [ 'assignment_id', 'hit_id', 'worker_id', tn, sn ] ]
# Out:
#                               assignment_id                          hit_id  \
# 10008362764  3H8DHMCCW9AAPBON41L4NK9Q830KDC  3ULIZ0H1V94BTDPERJS1V9TGIQA512
# 10028662223  3RWE2M8QWH9HYX8WP2PP056B8AH0NR  3VP28W7DUMJ0Q63B56E29F45KZ2FZL
# 10034622346  3OVR4I9USPIJ0I3POV48G2RTUU64QE  3CZH926SIBDSHVFQP246X16W72SE4W
# 10035378983  3OE22WJIGINIHGX431VQT6PNT7RQUK  3UUIU9GZC44C2X1NT2CB1FCBA8AT56
# 10038105563  3I33IC7ZWF1HAOHLVLOYXNFQ6122AT  3WJGKMRWVH8QKTE5MMZ4AH0ZZ40CD8
# 10072845645  3G2UL9A02DDN9N2OBKOHD9UCLQM67V  3ULIZ0H1V94BTDPERJS1V9TGIPZ51P
# 10090775625  3CFJTT4SXTP327XPDLX6ACKHUO77IU  3EQVJH0T4ZKOIQLIU4DKQCF1FISHT4
# 10098323464  3TXWC2NHNZPWA4OEXUP4SAHAYCGS92  3JVP4ZJHDORNYCZB2K7V6DEBIKBI0N
# 10099413984  32XVDSJFPZWICPQASOE36EAQ0F3M23  3OZ4VAIBEWEZMOKXNZGK37J1PUKVJ9
#
#                   worker_id tagged_Bright style_Bright
# 10008362764  A2NPNKSW89BODS         False        False
# 10028662223   AN3KR7C1SLYY3         False        False
# 10034622346  A1R02UXIIZL1SO          True        False
# 10035378983   ABICTZWG5DU3G          True        False
# 10038105563  A1GY4Z89KWHWZB         False        False
# 10072845645  A1OVDEQPK8O5PG         False        False
# 10090775625  A1WR2AKX164FZO         False        False
# 10098323464   AEVU71Z2FDTUX         False        False
# 10099413984  A1U3PULHJJGGCC          True        False
#
# [9 rows x 5 columns]

# %%
len( tag_df.dropna( subset=[sn] ) )
# Out:
# 1422

# %%
pred_list = tag_df[tn].astype(int)
truth_list = tag_df[sn].astype(int)
print len( pred_list ) == len( truth_list )
print array( [ p == t for p,t in zip( pred_list.index, truth_list.index )] ).all()
# Out:
# True
# True

# %%
import sklearn.metrics

# %%
print sklearn.metrics.accuracy_score( truth_list, pred_list )
print sklearn.metrics.precision_recall_fscore_support( truth_list, pred_list, pos_label=1, average='micro' )
# Out:
# 0.710267229255
# (0.70161290322580649, 0.7331460674157303, 0.71703296703296693, 712)

# %%
acc_l = []
pre_l = []
rec_l = []
len_l = []
cor_l = []

for sn in style_cols:
    
    tn = 'tagged_' + sn[6:]
    
    tag_df = result_df.dropna( subset=[tn] )
    
    pred_list = tag_df[tn].astype(int)
    truth_list = tag_df[sn].astype(int)
    
    acc = sklearn.metrics.accuracy_score( truth_list, pred_list )
    prec_rec = sklearn.metrics.precision_recall_fscore_support( truth_list, pred_list, pos_label=1, average='micro' )
    
    acc_l += [ acc ]
    pre_l += [ prec_rec[0] ]
    rec_l += [ prec_rec[1] ]
    len_l += [ len( truth_list ) ]
    cor_l += [ len( [ t for t in truth_list if t ] ) / float( len( truth_list ) ) ]

d = {
    'accuracy': pd.Series( acc_l, index=style_cols ),
    'precision': pd.Series( pre_l, index=style_cols ),
    'recall':  pd.Series( rec_l, index=style_cols ),
    '_length':  pd.Series( len_l, index=style_cols ),
    '_%true': pd.Series( cor_l, index=style_cols ),
}
pd.DataFrame( d )
# Out:
#                                _%true  _length  accuracy  precision    recall
# style_Bright                 0.500703     1422  0.710267   0.701613  0.733146
# style_Depth_of_Field         0.500510     1962  0.692661   0.687068  0.708758
# style_Detailed               0.501414     1061  0.612630   0.594976  0.712406
# style_Ethereal               0.500591     1692  0.802009   0.841333  0.744982
# style_Geometric_Composition  0.501575     1270  0.799213   0.860377  0.715856
# style_HDR                    0.500534     1872  0.738248   0.868204  0.562433
# style_Hazy                   0.500591     1692  0.789598   0.799026  0.774498
# style_Horror                 0.500838     1791  0.941932   0.943017  0.940914
# style_Long_Exposure          0.500526     1902  0.746057   0.868132  0.580882
# style_Macro                  0.500887     1691  0.913661   0.880565  0.957497
# style_Melancholy             0.500887     1691  0.668835   0.699583  0.593861
# style_Minimal                0.500591     1692  0.771277   0.790404  0.739079
# style_Noir                   0.500310     1611  0.891372   0.909209  0.869727
# style_Pastel                 0.500584     1712  0.652453   0.788546  0.417736
# style_Romantic               0.501020     1960  0.611224   0.794118  0.302444
# style_Serene                 0.500693     1442  0.701110   0.691700  0.727147
# style_Sunny                  0.500552     1812  0.834437   0.800793  0.890849
# style_Vintage                0.501289     1939  0.687983   0.750341  0.565844
#
# [18 rows x 5 columns]

# %% [markdown]
# # Representative images

# %%
sn = style_cols[1]
tn = 'tagged_' + sn[6:]
cn = 'conf_' + tn[7:]
print sn, tn, cn
# Out:
# style_Depth_of_Field tagged_Depth_of_Field conf_Depth_of_Field

# %%
tag_df = result_df.dropna( subset=[tn] )

# %%
images = tag_df.index.unique()
print len( images )
print images[:10]
# Out:
# 1962
# [u'10023941745' u'10056442674' u'10078352273' u'10086781783' u'10108582306'
#  u'10116691656' u'10124277176' u'10154052754' u'10157260155' u'10157599366']

# %%
img = images[2]

# %%
temp_df = tag_df.ix[ img ]

# %%
print len( temp_df )
print len( temp_df[ temp_df[tn] == True ] )
# Out:
# 45
# 30

# %%
tag_df.ix[img][cn]
# Out:
# 0.0

# %%
true_imgs = []
for i in range(4):
    true_imgs += [[]]

for img in images:
    
    cn = 'conf_' + tn[7:]
    
    true_len = int( tag_df.ix[img][cn] * 3 )
    
    true_imgs[ true_len ] += [ img ]

# %%
dis_html = '''
<table>
<tr>
<td width="50px">{}</td>
<td><img src="{}"></td>
<td><img src="{}"></td>
<td><img src="{}"></td>
<td><img src="{}"></td>
</tr>
</table>'''

# %%
from IPython.display import HTML

# %%
img_urls = tag_df.ix[ true_imgs[2][:4] ]['image_url'].unique()
img_urls
# Out:
# array(['http://farm6.staticflickr.com/5536/10302761004_6c079393c5.jpg',
#        'http://farm8.staticflickr.com/7382/10374898976_2baca0bf70.jpg',
#        'http://farm6.staticflickr.com/5480/10465321004_1ab1f8117a.jpg',
#        'http://farm8.staticflickr.com/7435/10533116146_83103c4e5a.jpg'], dtype=object)

# %%
HTML( dis_html.format( *( ['2 true'] + list( img_urls ) ) ) )
# Out:
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm6.staticflickr.com/5536/10302761004_6c079393c5.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7382/10374898976_2baca0bf70.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5480/10465321004_1ab1f8117a.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7435/10533116146_83103c4e5a.jpg"></td>
# </tr>
# </table>

# %%
def ranked_images_for_style( sn ):
    
    tn = 'tagged_' + sn[6:]
    cn = 'conf_' + tn[7:]    
    tag_df = result_df.dropna( subset=[tn] )

    images = tag_df.index.unique()

    true_imgs = []
    for i in range(4):
        true_imgs += [[]]

    for img in images:

        temp_df = tag_df.ix[img]
        true_len = int( tag_df.ix[img][cn] * 3 )

        true_imgs[ true_len ] += [ img ]
        
    return true_imgs

# %%
def display_ranked_images( sn ):
    
    true_imgs = ranked_images_for_style( sn )
        
    tn = 'tagged_' + sn[6:]
    tag_df = result_df.dropna( subset=[tn] )
    
    answer = ''
    
    for i in range( 4 ):
        img_urls = tag_df.ix[ true_imgs[i][:4] ]['image_url'].unique()
        result = dis_html.format( *( ['{} true'.format(i)] + list( img_urls ) ) )
        answer += result
        
    return HTML( answer )

# %%
i = 0
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Bright</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm3.staticflickr.com/2858/10008362764_4632f5585e.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5468/10028662223_8e6b7fcebd.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2813/10038105563_b1d22c5c1b.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2813/10090775625_5d120eca64.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm8.staticflickr.com/7459/10072845645_8abc71b436.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5502/10364524243_76db75658f.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5514/10389458135_71540584ac.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2849/10429426755_e88156fa14.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7439/10035378983_00346b56d8.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7447/10099413984_d914a6ec69.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3828/10116600103_32dd507579.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3824/10282567413_6fe71a19e1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm8.staticflickr.com/7368/10034622346_3314bc4cd0.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7454/10114140383_89780d8e30.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5532/10326271223_b1e20a5a2b.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5511/10669368643_93a9430db5.jpg"></td>
# </tr>
# </table>

# %%
i = 1
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Depth_of_Field</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3823/10056442674_2bd3097ef7.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5455/10078352273_f66bf3be9a.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7359/10086781783_5e9852c292.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7429/10116691656_0023447f24.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm8.staticflickr.com/7319/10023941745_66f27ca5c6.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3683/10108582306_9088def555.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3681/10124277176_2f4f8e741e.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3749/10224811456_f29ca4a3fa.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm6.staticflickr.com/5536/10302761004_6c079393c5.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7382/10374898976_2baca0bf70.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5480/10465321004_1ab1f8117a.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7435/10533116146_83103c4e5a.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm3.staticflickr.com/2879/10205241684_19585e78e7.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5529/10475974986_cf9fe142ff.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3680/10912551916_fdce7c7d90.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3719/10936478055_e1fd93701d.jpg"></td>
# </tr>
# </table>

# %%
i = 2
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Detailed</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm8.staticflickr.com/7291/10444377893_4cdf40b7b9.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3786/10459677215_4897fdaa25.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2876/10520306983_b9b4bd6818.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7334/10592624736_9b2b6faa6b.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm4.staticflickr.com/3772/10476420806_d57daeef87.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7320/10576485634_93863973c6.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3774/10581625614_312821e1de.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2873/10588336744_a7989ff681.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3814/10004468814_81758e6929.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5500/10004487845_6a0b8f897e.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5504/10185200854_887453a44b.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3695/10189514866_bb28be9d01.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3795/10226768596_be9a8da1d9.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2809/10442898363_1a220df2db.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3776/10472347373_0a937264d6.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2820/10976002644_1635f750ee.jpg"></td>
# </tr>
# </table>

# %%
i = 3
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Ethereal</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3783/10004268914_4363ccf9c9.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2855/10014486544_5c8b62e1a9.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7382/10047999266_a12ab2d010.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2863/10101815525_049d034a6d.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5329/10182086366_cb7739f5eb.jpg"></td>
# <td><img src="http://farm2.staticflickr.com/1214/1048828405_5682be87df.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5549/10532396953_a472031aff.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3679/10582086045_76399247cc.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7411/10409103024_9f85f75cc1.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5506/10615696915_02cbbde245.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7450/10713128903_0586f20641.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2827/11061054304_17a666749a.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm8.staticflickr.com/7436/10343825145_edb14d3890.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2818/10360867873_33afde2e6d.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7382/10374898976_2baca0bf70.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7372/10440778115_020208433f.jpg"></td>
# </tr>
# </table>

# %%
i = 4
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Geometric_Composition</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm3.staticflickr.com/2890/10037844055_4c2a24c96c.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7383/10068170155_6f53a681d7.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5547/10090338704_e5856660c7.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7422/10116455975_1f1c06775a.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm8.staticflickr.com/7305/10255375166_b989d45df7.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7359/10278289415_0ab9c1cbfd.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5527/10429074886_a0745ca1bf.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7317/10559894533_3c4f3048ef.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3689/10089575255_0bac821e9a.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7358/10457382966_a0aa73251e.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7330/10939100025_3d7a20bf60.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7327/11193491156_c5a521990e.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3807/10083561356_8592046850.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7326/10101977363_fe9d643803.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7411/10271825123_f6816a0f0d.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7395/10589994623_7898189209.jpg"></td>
# </tr>
# </table>

# %%
i = 5
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_HDR</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm8.staticflickr.com/7379/10031022454_cecf032e32.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3783/10070934124_41b35d3e48.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2882/10087927774_3c410b03a9.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5537/10116056393_81c4ae89f8.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5476/10038547923_d7ef0460a9.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7397/10114399816_4451e145f8.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3750/10313748643_8e287494ba.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3724/10338631804_d4ab5f75a3.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7460/10193985764_e13da130fb.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3760/10352968885_80991b208c.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5510/10749342613_26d34744a6.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3677/11163933943_54ea9c08f1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3793/10778984886_9bdbbf4a59.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7320/11049739715_244685676a.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2811/11090050663_be33768d5d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3667/11950819616_14a44ce586.jpg"></td>
# </tr>
# </table>

# %%
i = 6
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Hazy</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3793/10051348025_5f4463021d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3694/10075499944_c867cfe16b.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7305/10097471523_84bf198c3d.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7447/10115771633_fc76bb87e1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm8.staticflickr.com/7308/10142659953_7a13680790.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2859/10377768576_5ebdf022c7.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5482/10474936703_433a61b30c.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7393/10485942113_914b0a8029.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm3.staticflickr.com/2836/10014552266_cf54bd864b.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7380/10119108653_4d26824b34.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5529/10211144636_d5d90833b1.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7416/10322257946_05af9f705d.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm6.staticflickr.com/5504/10168045053_9eb25962f6.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3709/10168598443_0941f530b8.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5478/10232334366_c26056f3c0.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5523/10470583354_ca804ccfa8.jpg"></td>
# </tr>
# </table>

# %%
i = 7
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Horror</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm6.staticflickr.com/5490/10029322395_cfb927ca12.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5451/10033541236_61fce51da3.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7368/10034622346_3314bc4cd0.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7417/10057657744_1616f219fe.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm8.staticflickr.com/7420/10033500453_7ac104beb4.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5471/10074914174_82a53efc1f.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7448/10098027215_d637ec6333.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3780/10340184953_5f4b72a188.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3676/10319071894_780b619f0d.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7409/10419438015_bc39ce424d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3736/10472782033_9459cd5029.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7302/10474807143_9d5a4dc4f7.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3775/10059002904_d13ceb631e.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7369/10061654134_cf17dceec3.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5531/10091494186_41c7460a35.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2863/10092897583_df4f5eff5b.jpg"></td>
# </tr>
# </table>

# %%
i = 8
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Long_Exposure</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm8.staticflickr.com/7438/10002847526_7d67c6caff.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3700/10028371516_c02b635bf4.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5344/10028469586_8c24aaa235.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3711/10056793076_f75bce6b8b.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm3.staticflickr.com/2834/10365127535_993d48dc60.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5480/10398144204_354223a55b.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7391/10491143634_b45d52182c.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2875/10606420655_6d13bc6be9.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm6.staticflickr.com/5482/10474936703_433a61b30c.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5484/10579878365_0c0e7097fd.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7457/10838534953_165507ff91.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7400/10913789284_14a8de0dd7.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3697/10430585503_a943df8fa1.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5493/10729225135_3f347907b5.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5513/11111640244_16b1d051eb.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3814/11340044713_4dd20885ba.jpg"></td>
# </tr>
# </table>

# %%
i = 9
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Macro</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm6.staticflickr.com/5491/10073980984_1f9c844203.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7430/10133838976_2f35c56e57.jpg"></td>
# <td><img src="http://farm9.staticflickr.com/8412/10174228736_c4d48e811c.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7326/10180320474_844254fc91.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm4.staticflickr.com/3784/10075073154_e3f08b170e.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7415/10165079654_6555315aa3.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7298/10254441153_8a4950fc31.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3789/10641903944_ee76095b00.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3748/10615282516_481a9e113f.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2890/10854665514_63b35d88f3.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3764/11360176505_e7a41a690f.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5527/11912240886_ca52fe9916.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3678/10143373316_612296b46b.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3774/10291545395_dd8501c2c4.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3674/10502761666_5027ecb059.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7365/10510762803_d9d8a55f61.jpg"></td>
# </tr>
# </table>

# %%
i = 10
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Melancholy</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3783/10004268914_4363ccf9c9.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3665/10035977325_9fd63021a8.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7388/10060413064_13171775ac.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7446/10072745184_79d437bb1f.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm4.staticflickr.com/3820/10043101016_04a6920fa1.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5474/10046569103_a7fc8cbd98.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2864/10083113565_ff7ceef614.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7294/10117664354_d152a5fe37.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7428/10119353396_36a749b3b0.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3807/10364362005_07f0af5e15.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5515/10467424643_4805215070.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7325/10479570934_474692a36e.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm3.staticflickr.com/2848/10233596924_ae3119010a.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5495/10500511624_03fba3fbd8.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7447/10626064715_355bd7207d.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5549/10775687385_afd23ed74d.jpg"></td>
# </tr>
# </table>

# %%
i = 11
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Minimal</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3827/10026982266_85e99fe5d9.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5531/10147089744_7d2b54df5b.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5504/10168045053_9eb25962f6.jpg"></td>
# <td><img src="http://farm9.staticflickr.com/8411/10176809654_dcb7ae13b1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5475/10045237036_cbfe540327.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7364/10157474124_c77e4c58c8.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3747/10181637513_1520b32fab.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5496/10226503083_16bdfd1854.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7413/10247768376_a324f23043.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5342/10255867664_139a388c23.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7373/10449421913_6d5a6f2ab6.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2838/10484774553_f60f8b4401.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm8.staticflickr.com/7413/10440778165_7e143f4f70.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3798/10455198154_ea6def829d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3819/10471022024_d11e2cb744.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3747/10625757904_b904f0f91f.jpg"></td>
# </tr>
# </table>

# %%
i = 12
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Noir</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm6.staticflickr.com/5329/10009898286_79d1d126be.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2852/10043322025_89e9948c17.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5475/10045237036_cbfe540327.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5479/10074119863_bdf10d74c1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm4.staticflickr.com/3720/10266386824_2a829c407e.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3756/10369124753_e9c39bb066.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3704/10425581056_0af27e6d6b.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2824/10856077394_e156d2f3dd.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3795/10171999405_7ed789d4d7.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3781/10195630185_4d20cef65d.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5511/10225474813_055be0a56d.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5332/10256528456_d2f23f2874.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm3.staticflickr.com/2827/10115889755_f9ea9f2a24.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7298/10439010595_db3d1e839d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3796/10482108644_bb267450a1.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3748/10490868586_87110ea7e8.jpg"></td>
# </tr>
# </table>

# %%
i = 13
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Pastel</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm6.staticflickr.com/5459/10007533796_26efca4bca.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3665/10020861183_46e0fbd458.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3694/10075499944_c867cfe16b.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3785/10091938423_a332166f83.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5488/10035946813_1217e573b9.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2823/10042097516_f7943641f5.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5323/10141770564_a109d77def.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2887/10256077443_49e6264080.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm4.staticflickr.com/3822/10156987796_211f724e53.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2876/10197884156_27fe172561.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7382/10374898976_2baca0bf70.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7313/10379288353_22d2f870bc.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm8.staticflickr.com/7308/10205570945_063e952b54.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5539/10494092756_ecf7bbf312.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3734/10547031685_9101253a46.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5520/10613233006_40e8681059.jpg"></td>
# </tr>
# </table>

# %%
i = 14
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Romantic</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm6.staticflickr.com/5480/10007199026_fa6c61e1b4.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5495/10008818046_7eb2101e77.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2865/10029131723_b83b5b71b6.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7353/10033305173_6ee5fab67e.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5327/10059179434_8057889078.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5517/10237450664_aedd8a9392.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5511/10251239796_d361063ef8.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2817/10278011886_52d53dd975.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm3.staticflickr.com/2837/10083205423_e90574965f.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2880/10126036193_56a2525b51.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5483/10166355795_fc96db1af6.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5521/10202777475_df565f27f6.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3755/10251151444_a428341cfd.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2831/10432037564_5055995954.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7401/10788991713_055b0f58b8.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5545/11392470513_552d12b2ed.jpg"></td>
# </tr>
# </table>

# %%
i = 15
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Serene</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3795/10049444715_c6a0439ea5.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5509/10071957936_ba786df9ee.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7426/10152886035_e88858c18e.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3702/10165055184_e3bb2b6967.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm3.staticflickr.com/2836/10014552266_cf54bd864b.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3781/10195630185_4d20cef65d.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2813/10311137974_7ecf09f3bf.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3774/10553061135_246979b8ab.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7451/10258628866_84c14c3fce.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7301/10333516884_f9c9a8a733.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2858/10353490423_a25cbd9d4e.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7352/10857999456_07906a93d1.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm6.staticflickr.com/5448/10065189736_55d3e5dc88.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5523/10065246986_13eacc28ee.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7307/10329342783_35ef102652.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5480/10540214903_9c625f8859.jpg"></td>
# </tr>
# </table>

# %%
i = 16
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Sunny</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm4.staticflickr.com/3777/10034330946_7e08328c0b.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3824/10072846474_de0aca2ab7.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7380/10108676256_84a1468744.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7362/10168533644_8f5e7f46bc.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm6.staticflickr.com/5345/10020718036_ae4d1db431.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3809/10049291514_15ac7e7a39.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3718/10059504584_c710f9aeee.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2828/10119801055_f1e4399758.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7435/10140940884_92544a5ba9.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5481/10146124724_b60da80d7a.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5487/11091812756_49b5dd21d3.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7452/11300139416_f48a35960e.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3757/10334457595_83956030f3.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5508/10356768714_db2a2311ea.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7375/10632058395_75dd43d0ce.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2811/10640918385_5fff1edb51.jpg"></td>
# </tr>
# </table>

# %%
i = 17
sn = style_cols[i]
display( HTML( '''<h1>{}</h1>'''.format(sn) ) )
display( display_ranked_images( sn ) )
# Out:
# <h1>style_Vintage</h1>
# <table>
# <tr>
# <td width="50px">0 true</td>
# <td><img src="http://farm8.staticflickr.com/7405/10043299124_5d903307bb.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3771/10052565753_04f8aca846.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5442/10060153393_e85ea000ba.jpg"></td>
# <td><img src="http://farm3.staticflickr.com/2891/10065934123_5029a60a35.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">1 true</td>
# <td><img src="http://farm3.staticflickr.com/2880/10204417464_9f07ea9c7c.jpg"></td>
# <td><img src="http://farm9.staticflickr.com/8417/10211767013_87f19aba3d.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3800/10300247874_cf9160c6e3.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7383/10380940284_145a6b4ccb.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">2 true</td>
# <td><img src="http://farm8.staticflickr.com/7291/10037984654_310b3c95a7.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5534/10299302556_e1a6b844ba.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3781/10535597606_ceae128c92.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7292/10806457453_b30ed94506.jpg"></td>
# </tr>
# </table>
# <table>
# <tr>
# <td width="50px">3 true</td>
# <td><img src="http://farm4.staticflickr.com/3795/10049444715_c6a0439ea5.jpg"></td>
# <td><img src="http://farm8.staticflickr.com/7346/10257711953_05a2977ec9.jpg"></td>
# <td><img src="http://farm4.staticflickr.com/3670/10471070205_2a6cd6cbef.jpg"></td>
# <td><img src="http://farm6.staticflickr.com/5479/10808629054_dac4f2bb1f.jpg"></td>
# </tr>
# </table>
